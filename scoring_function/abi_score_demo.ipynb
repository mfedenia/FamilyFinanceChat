# %% [markdown]
# # ABI Trust + Question Quality Scoring Demo
#
# This notebook demonstrates how to use `score.py` to evaluate a full conversation.
#
# **Requirements:**
#
# - `middleware.py` with the ABI Trust Pipe implementation (TrustState / APIScorer / ABIEngine / Gate / GateInputs / GateResult / BasePipe).
# - `score.py` in the same directory as this notebook (the file that defines `score_conversation`).
#
# The notebook will:
# 1. Construct a demo conversation.
# 2. Run `score_conversation` with `use_trust=True` (trust + ABI + question quality + gate).
# 3. Run `score_conversation` with `use_trust=False` (only question quality + gate).

# %%
from google.colab import drive
from pathlib import Path
drive.mount('/content/drive')

PROJ = Path('/content/drive/MyDrive/rag_bio_project').resolve()
print('Project path:', PROJ)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Project path: /content/drive/MyDrive/rag_bio_project

# %%
# 挂载 + 切目录 + 修正 sys.path（Colab 一次性修好路径）
from google.colab import drive
drive.mount('/content/drive')

import os, sys, pathlib

PROJ = "/content/drive/MyDrive/rag_bio_project"
assert os.path.exists(PROJ), f"项目目录不存在: {PROJ}"

# 让 Python 能在该目录下找模块
if PROJ not in sys.path:
    sys.path.insert(0, PROJ)

# 切换工作目录（可选，但推荐）
os.chdir(PROJ)

# 检查模块是否真的在那儿
print("CWD:", os.getcwd())
print("Has module:", os.path.exists("abi_trust_pipeline.py"))
# !ls -l abi_trust_pipeline.py
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# CWD: /content/drive/MyDrive/rag_bio_project
# Has module: True
# -rw------- 1 root root 33116 Nov 28 11:12 abi_trust_pipeline.py

# %%
import json
from typing import List, Dict

from score import score_conversation

def make_demo_conversation() -> List[Dict[str, str]]:
    """Construct a simple demo conversation in OpenAI messages format."""
    return [
        {
            "role": "system",
            "content": "You are a careful financial advisor that answers in Chinese.",
        },
        {
            "role": "user",
            "content": "请问如果我每个月收入一万块，大概应该存多少钱比较合适？",
        },
        {
            "role": "assistant",
            "content": "一般可以从20%-30%开始，根据你的风险偏好和现有负债做微调。",
        },
        {
            "role": "user",
            "content": "如果突然失业三个月，我现在应该准备多少紧急备用金？",
        },
        {
            "role": "assistant",
            "content": "通常建议准备3-6个月的基本生活支出作为紧急预备金。",
        },
        {
            "role": "user",
            "content": "那我应该先还信用卡还是先存钱做投资？",
        },
    ]

print("Demo conversation constructed with", len(make_demo_conversation()), "messages.")
# Out:
# Demo conversation constructed with 6 messages.

# %%
conv = make_demo_conversation()

# Mode 1: include trust & ABI in the score
res_trust = score_conversation(
    conv,
    use_mock_scores=True,   # use mock ABI scores for offline testing
    use_trust=True,
)

# Mode 2: use only question quality + gate
res_no_trust = score_conversation(
    conv,
    use_mock_scores=True,
    use_trust=False,
)

print("=" * 80)
print("use_trust = True (trust + ABI + question quality + gate)")
print("=" * 80)
print(json.dumps(res_trust, ensure_ascii=False, indent=2))

print("\n" + "=" * 80)
print("use_trust = False (question quality + gate only)")
print("=" * 80)
print(json.dumps(res_no_trust, ensure_ascii=False, indent=2))
# Out:
# ================================================================================
# use_trust = True (trust + ABI + question quality + gate)
# ================================================================================
# {
#   "conversation_overall_0_100": 75.3,
#   "use_trust": true,
#   "final_stage": "knowledge",
#   "final_trust_weighted_0_1": 0.691,
#   "final_A": 0.664,
#   "final_B": 0.594,
#   "final_I": 1.0,
#   "stage_trajectory": [
#     "contract",
#     "contract",
#     "knowledge",
#     "knowledge"
#   ],
#   "n_user_turns": 3,
#   "turn_scores": [
#     {
#       "overall_0_100": 83.2,
#       "use_trust": true,
#       "weights_effective": {
#         "trust": 0.4,
#         "abi": 0.2,
#         "question": 0.3,
#         "gate": 0.1
#       },
#       "components": {
#         "trust_long_0_1": 0.812,
#         "abi_local_0_1": 0.767,
#         "abi_delta_mag": 0.1272,
#         "question_quality_0_1": 0.929,
#         "question_habit_0_1": 0.929,
#         "gate_p_answer_0_1": 0.748
#       },
#       "abi": {
#         "A_local": 0.717,
#         "B_local": 0.699,
#         "I_local": 0.885,
#         "A_after": 0.554,
#         "B_after": 0.52,
#         "I_after": 1.0,
#         "dA": 0.0541,
#         "dB": 0.0199,
#         "dI": 0.3076,
#         "stage_before": "contract",
#         "stage_after": "contract"
#       },
#       "gate": {
#         "p_answer": 0.748,
#         "rationale": {
#           "trust": 0.8123779411764706,
#           "non_private": 1,
#           "polite": 1,
#           "preamble": 1,
#           "linear_score": 1.087231470588235
#         }
#       },
#       "question": {
#         "text": "请问如果我每个月收入一万块，大概应该存多少钱比较合适？",
#         "score_total_0_14": 13,
#         "verdict": "good",
#         "notes": "heuristic scorer"
#       },
#       "turn_index": 1
#     },
#     {
#       "overall_0_100": 73.7,
#       "use_trust": true,
#       "weights_effective": {
#         "trust": 0.4,
#         "abi": 0.2,
#         "question": 0.3,
#         "gate": 0.1
#       },
#       "components": {
#         "trust_long_0_1": 0.648,
#         "abi_local_0_1": 0.767,
#         "abi_delta_mag": 0.0269,
#         "question_quality_0_1": 0.857,
#         "question_habit_0_1": 0.857,
#         "gate_p_answer_0_1": 0.674
#       },
#       "abi": {
#         "A_local": 0.717,
#         "B_local": 0.699,
#         "I_local": 0.885,
#         "A_after": 0.614,
#         "B_after": 0.541,
#         "I_after": 1.0,
#         "dA": 0.06,
#         "dB": 0.0207,
#         "dI": 0.0,
#         "stage_before": "contract",
#         "stage_after": "knowledge"
#       },
#       "gate": {
#         "p_answer": 0.674,
#         "rationale": {
#           "trust": 0.6477921046875,
#           "non_private": 1,
#           "polite": 1,
#           "preamble": 1,
#           "linear_score": 0.7251426303124999
#         }
#       },
#       "question": {
#         "text": "如果突然失业三个月，我现在应该准备多少紧急备用金？",
#         "score_total_0_14": 12,
#         "verdict": "good",
#         "notes": "heuristic scorer"
#       },
#       "turn_index": 3
#     },
#     {
#       "overall_0_100": 68.9,
#       "use_trust": true,
#       "weights_effective": {
#         "trust": 0.4,
#         "abi": 0.2,
#         "question": 0.3,
#         "gate": 0.1
#       },
#       "components": {
#         "trust_long_0_1": 0.691,
#         "abi_local_0_1": 0.749,
#         "abi_delta_mag": 0.0347,
#         "question_quality_0_1": 0.643,
#         "question_habit_0_1": 0.643,
#         "gate_p_answer_0_1": 0.694
#       },
#       "abi": {
#         "A_local": 0.664,
#         "B_local": 0.699,
#         "I_local": 0.885,
#         "A_after": 0.664,
#         "B_after": 0.594,
#         "I_after": 1.0,
#         "dA": 0.0504,
#         "dB": 0.0538,
#         "dI": 0.0,
#         "stage_before": "knowledge",
#         "stage_after": "knowledge"
#       },
#       "gate": {
#         "p_answer": 0.694,
#         "rationale": {
#           "trust": 0.6911862074177083,
#           "non_private": 1,
#           "polite": 1,
#           "preamble": 1,
#           "linear_score": 0.820609656318958
#         }
#       },
#       "question": {
#         "text": "那我应该先还信用卡还是先存钱做投资？",
#         "score_total_0_14": 9,
#         "verdict": "okay",
#         "notes": "heuristic scorer"
#       },
#       "turn_index": 5
#     }
#   ],
#   "question_quality_agg": {
#     "count": 3,
#     "avg_total_0_14": 11.33,
#     "overall_0_100": 81,
#     "distribution": {
#       "0-3": 0,
#       "4-6": 0,
#       "7-10": 1,
#       "11-14": 2
#     },
#     "per_dimension_avg": {
#       "relevance": 1.67,
#       "politeness": 1.33,
#       "on_topic": 1.67,
#       "neutrality": 1.67,
#       "non_imperative": 2.0,
#       "clarity_optional": 1.0,
#       "privacy_minimization_optional": 2.0
#     },
#     "habit_feedback": [
#       "Requests avoid direct commands—good style.",
#       "Minimal personal data requested."
#     ]
#   }
# }
#
# ================================================================================
# use_trust = False (question quality + gate only)
# ================================================================================
# {
#   "conversation_overall_0_100": 78.3,
#   "use_trust": false,
#   "final_stage": "knowledge",
#   "final_trust_weighted_0_1": 0.691,
#   "final_A": 0.664,
#   "final_B": 0.594,
#   "final_I": 1.0,
#   "stage_trajectory": [
#     "contract",
#     "contract",
#     "knowledge",
#     "knowledge"
#   ],
#   "n_user_turns": 3,
#   "turn_scores": [
#     {
#       "overall_0_100": 88.3,
#       "use_trust": false,
#       "weights_effective": {
#         "trust": 0.0,
#         "abi": 0.0,
#         "question": 0.75,
#         "gate": 0.25
#       },
#       "components": {
#         "trust_long_0_1": 0.812,
#         "abi_local_0_1": 0.767,
#         "abi_delta_mag": 0.1272,
#         "question_quality_0_1": 0.929,
#         "question_habit_0_1": 0.929,
#         "gate_p_answer_0_1": 0.748
#       },
#       "abi": {
#         "A_local": 0.717,
#         "B_local": 0.699,
#         "I_local": 0.885,
#         "A_after": 0.554,
#         "B_after": 0.52,
#         "I_after": 1.0,
#         "dA": 0.0541,
#         "dB": 0.0199,
#         "dI": 0.3076,
#         "stage_before": "contract",
#         "stage_after": "contract"
#       },
#       "gate": {
#         "p_answer": 0.748,
#         "rationale": {
#           "trust": 0.8123779411764706,
#           "non_private": 1,
#           "polite": 1,
#           "preamble": 1,
#           "linear_score": 1.087231470588235
#         }
#       },
#       "question": {
#         "text": "请问如果我每个月收入一万块，大概应该存多少钱比较合适？",
#         "score_total_0_14": 13,
#         "verdict": "good",
#         "notes": "heuristic scorer"
#       },
#       "turn_index": 1
#     },
#     {
#       "overall_0_100": 81.1,
#       "use_trust": false,
#       "weights_effective": {
#         "trust": 0.0,
#         "abi": 0.0,
#         "question": 0.75,
#         "gate": 0.25
#       },
#       "components": {
#         "trust_long_0_1": 0.648,
#         "abi_local_0_1": 0.767,
#         "abi_delta_mag": 0.0269,
#         "question_quality_0_1": 0.857,
#         "question_habit_0_1": 0.857,
#         "gate_p_answer_0_1": 0.674
#       },
#       "abi": {
#         "A_local": 0.717,
#         "B_local": 0.699,
#         "I_local": 0.885,
#         "A_after": 0.614,
#         "B_after": 0.541,
#         "I_after": 1.0,
#         "dA": 0.06,
#         "dB": 0.0207,
#         "dI": 0.0,
#         "stage_before": "contract",
#         "stage_after": "knowledge"
#       },
#       "gate": {
#         "p_answer": 0.674,
#         "rationale": {
#           "trust": 0.6477921046875,
#           "non_private": 1,
#           "polite": 1,
#           "preamble": 1,
#           "linear_score": 0.7251426303124999
#         }
#       },
#       "question": {
#         "text": "如果突然失业三个月，我现在应该准备多少紧急备用金？",
#         "score_total_0_14": 12,
#         "verdict": "good",
#         "notes": "heuristic scorer"
#       },
#       "turn_index": 3
#     },
#     {
#       "overall_0_100": 65.6,
#       "use_trust": false,
#       "weights_effective": {
#         "trust": 0.0,
#         "abi": 0.0,
#         "question": 0.75,
#         "gate": 0.25
#       },
#       "components": {
#         "trust_long_0_1": 0.691,
#         "abi_local_0_1": 0.749,
#         "abi_delta_mag": 0.0347,
#         "question_quality_0_1": 0.643,
#         "question_habit_0_1": 0.643,
#         "gate_p_answer_0_1": 0.694
#       },
#       "abi": {
#         "A_local": 0.664,
#         "B_local": 0.699,
#         "I_local": 0.885,
#         "A_after": 0.664,
#         "B_after": 0.594,
#         "I_after": 1.0,
#         "dA": 0.0504,
#         "dB": 0.0538,
#         "dI": 0.0,
#         "stage_before": "knowledge",
#         "stage_after": "knowledge"
#       },
#       "gate": {
#         "p_answer": 0.694,
#         "rationale": {
#           "trust": 0.6911862074177083,
#           "non_private": 1,
#           "polite": 1,
#           "preamble": 1,
#           "linear_score": 0.820609656318958
#         }
#       },
#       "question": {
#         "text": "那我应该先还信用卡还是先存钱做投资？",
#         "score_total_0_14": 9,
#         "verdict": "okay",
#         "notes": "heuristic scorer"
#       },
#       "turn_index": 5
#     }
#   ],
#   "question_quality_agg": {
#     "count": 3,
#     "avg_total_0_14": 11.33,
#     "overall_0_100": 81,
#     "distribution": {
#       "0-3": 0,
#       "4-6": 0,
#       "7-10": 1,
#       "11-14": 2
#     },
#     "per_dimension_avg": {
#       "relevance": 1.67,
#       "politeness": 1.33,
#       "on_topic": 1.67,
#       "neutrality": 1.67,
#       "non_imperative": 2.0,
#       "clarity_optional": 1.0,
#       "privacy_minimization_optional": 2.0
#     },
#     "habit_feedback": [
#       "Requests avoid direct commands—good style.",
#       "Minimal personal data requested."
#     ]
#   }
# }
